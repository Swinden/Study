# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns; sns.set()

# %%
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=100, centers=2, random_state=0, cluster_std=0.50)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='summer');

# %%
ax = plt.axes()
xfit = np.linspace(-1, 3.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='summer')
ax.plot([0.6], [2.1], 'x', color='black', markeredgewidth=4, markersize=12)
for (m, b) in [(1, 0.65), (0.5, 1.6), (-0.2, 2.9)]:
   ax.plot(xfit, m * xfit + b, '-k')
plt.xlim(-1, 3.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\代码库\机器学习\支持向量机\python\example2.ipynb Cell 3 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/e%3A/%E4%BB%A3%E7%A0%81%E5%BA%93/%E6%9C%BA%E5%99%A8%E5%AD%A6%E4%B9%A0/%E6%94%AF%E6%8C%81%E5%90%91%E9%87%8F%E6%9C%BA/python/example2.ipynb#ch0000002?line=4'>5</a> for (m, b) in [(1, 0.65), (0.5, 1.6), (-0.2, 2.9)]:
#       <a href='vscode-notebook-cell:/e%3A/%E4%BB%A3%E7%A0%81%E5%BA%93/%E6%9C%BA%E5%99%A8%E5%AD%A6%E4%B9%A0/%E6%94%AF%E6%8C%81%E5%90%91%E9%87%8F%E6%9C%BA/python/example2.ipynb#ch0000002?line=5'>6</a>    ax.plot(xfit, m * xfit + b, '-k')
# ----> <a href='vscode-notebook-cell:/e%3A/%E4%BB%A3%E7%A0%81%E5%BA%93/%E6%9C%BA%E5%99%A8%E5%AD%A6%E4%B9%A0/%E6%94%AF%E6%8C%81%E5%90%91%E9%87%8F%E6%9C%BA/python/example2.ipynb#ch0000002?line=6'>7</a> plt.xlim(-1, 3.5)
#
# TypeError: 'tuple' object is not callable

# %%
for (m, b) in [(1, 0.65), (0.5, 1.6), (-0.2, 2.9)]:
    print(m, b)
# Out:
# 1 0.65
# 0.5 1.6
# -0.2 2.9

# %%
xfit = np.linspace(-1, 3.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='summer')
for m, b, d in [(1, 0.65, 0.33), (0.5, 1.6, 0.55), (-0.2, 2.9, 0.2)]:
    yfit = m * xfit + b
    ax.plot(xfit, yfit, '-k')
    plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',\
        color='#AAAAAA', alpha=0.4)
plt.xlim(-1, 3.5);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\代码库\机器学习\支持向量机\python\example2.ipynb Cell 5 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/e%3A/%E4%BB%A3%E7%A0%81%E5%BA%93/%E6%9C%BA%E5%99%A8%E5%AD%A6%E4%B9%A0/%E6%94%AF%E6%8C%81%E5%90%91%E9%87%8F%E6%9C%BA/python/example2.ipynb#ch0000003?line=4'>5</a>     ax.plot(xfit, yfit, '-k')
#       <a href='vscode-notebook-cell:/e%3A/%E4%BB%A3%E7%A0%81%E5%BA%93/%E6%9C%BA%E5%99%A8%E5%AD%A6%E4%B9%A0/%E6%94%AF%E6%8C%81%E5%90%91%E9%87%8F%E6%9C%BA/python/example2.ipynb#ch0000003?line=5'>6</a>     plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',\
#       <a href='vscode-notebook-cell:/e%3A/%E4%BB%A3%E7%A0%81%E5%BA%93/%E6%9C%BA%E5%99%A8%E5%AD%A6%E4%B9%A0/%E6%94%AF%E6%8C%81%E5%90%91%E9%87%8F%E6%9C%BA/python/example2.ipynb#ch0000003?line=6'>7</a>         color='#AAAAAA', alpha=0.4)
# ----> <a href='vscode-notebook-cell:/e%3A/%E4%BB%A3%E7%A0%81%E5%BA%93/%E6%9C%BA%E5%99%A8%E5%AD%A6%E4%B9%A0/%E6%94%AF%E6%8C%81%E5%90%91%E9%87%8F%E6%9C%BA/python/example2.ipynb#ch0000003?line=7'>8</a> plt.xlim(-1, 3.5)
#
# TypeError: 'tuple' object is not callable

# %%
from sklearn.svm import SVC # "Support vector classifier"
model = SVC(kernel='linear', C=1E10)
model.fit(X, y)
# Out:
# SVC(C=10000000000.0, kernel='linear')
